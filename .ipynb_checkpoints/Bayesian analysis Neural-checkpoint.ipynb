# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import langevin_cached_model as lcm
import pymc3 as pm
import scipy.io

# %%
oxy_data37=scipy.io.loadmat('OXY37_MRI_1_ts.mat')

# %%
mpfc_r_ts=oxy_data37['mpfc_r_ts']
plt.plot(mpfc_r_ts[0])
print("mean: ",mpfc_r_ts[0].mean())
print("var: ",mpfc_r_ts[0].std()**2)
N=len(mpfc_r_ts[0])
print("N: ",N)
# Out:
# mean:  -1.13130760798e-12
# var:  371.985450742
# N:  736

# %%
# initial prior
# both D and A have mean 1 and std 10
alpha_A=400.0/16.0
beta_A=1.0/16.0
alpha_N=400.0/16.0
beta_N=1.0/16.0
alpha_D=2.0+1.0/1.6
beta_D=100*(alpha_D-1)
delta_t=0.802

# %%
# compile model for reuse
sm = lcm.LangevinPlusNoiseIG()
sm.samples=10000

# %%
trace = sm.run(x=mpfc_r_ts[0],
                aD=alpha_D,
                bD=beta_D,
                aA=alpha_A,
                bA=beta_A,
                aN=alpha_N,
                bN=beta_N,
                delta_t=delta_t,
                N=N)
# Out:
# Applied log-transform to D and added transformed D_log to model.
# Applied log-transform to A and added transformed A_log to model.
# Applied log-transform to sN and added transformed sN_log to model.
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-74-5f1122c55fed> in <module>()
#       6                 aN=alpha_N,
#       7                 bN=beta_N,
# ----> 8                 delta_t=delta_t)
#
# /Users/hstrey/Documents/Lab/programming/PythonProjects/Bayesian Analysis/langevin_cached_model.py in run(self, reinit, **inputs)
#      61
#      62     def run(self, reinit=True, **inputs):
# ---> 63         if self.cached_model is None:
#      64             self.cache_model(**inputs)
#      65
#
# /Users/hstrey/Documents/Lab/programming/PythonProjects/Bayesian Analysis/langevin_cached_model.py in cache_model(self, **inputs)
#      48
#      49     def cache_model(self, **inputs):
# ---> 50         self.shared_vars = self._create_shared_vars(**inputs)
#      51         self.cached_model = self.create_model(**self.shared_vars)
#      52
#
# /Users/hstrey/Documents/Lab/programming/PythonProjects/Bayesian Analysis/langevin_cached_model.py in create_model(self, x, aD, bD, aA, bA, aN, bN, delta_t, N)
#     126
#     127             B = pm.Deterministic('B', pm.exp(-delta_t * D / A))
# --> 128
#     129             path = Ornstein_Uhlenbeck('path',D=D, A=A, B=B)
#     130
#
# /Users/hstrey/anaconda/envs/python3/lib/python3.5/site-packages/pymc3/distributions/distribution.py in __new__(cls, name, *args, **kwargs)
#      23             data = kwargs.pop('observed', None)
#      24             dist = cls.dist(*args, **kwargs)
# ---> 25             return model.Var(name, dist, data)
#      26         elif name is None:
#      27             return object.__new__(cls)  # for pickle
#
# /Users/hstrey/anaconda/envs/python3/lib/python3.5/site-packages/pymc3/model.py in Var(self, name, dist, data)
#     254         if data is None:
#     255             if getattr(dist, "transform", None) is None:
# --> 256                 var = FreeRV(name=name, distribution=dist, model=self)
#     257                 self.free_RVs.append(var)
#     258             else:
#
# /Users/hstrey/anaconda/envs/python3/lib/python3.5/site-packages/pymc3/model.py in __init__(self, type, owner, index, name, distribution, model)
#     477             self.distribution = distribution
#     478             self.tag.test_value = np.ones(
# --> 479                 distribution.shape, distribution.dtype) * distribution.default()
#     480             self.logp_elemwiset = distribution.logp(self)
#     481             self.model = model
#
# /Users/hstrey/anaconda/envs/python3/lib/python3.5/site-packages/pymc3/distributions/distribution.py in default(self)
#      49
#      50     def default(self):
# ---> 51         return self.get_test_val(self.testval, self.defaults)
#      52
#      53
#
# /Users/hstrey/anaconda/envs/python3/lib/python3.5/site-packages/pymc3/distributions/distribution.py in get_test_val(self, val, defaults)
#      62         if val is None:
#      63             raise AttributeError(str(self) + " has no finite default value to use, checked: " +
# ---> 64                          str(defaults) + " pass testval argument or adjust so value is finite.")
#      65
#      66
#
# AttributeError: <langevin_cached_model.Ornstein_Uhlenbeck object at 0x12f346978> has no finite default value to use, checked: ['median', 'mean', 'mode'] pass testval argument or adjust so value is finite.

# %%
pm.traceplot(trace)

# %%
pm.summary(trace)

# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
SMALL_SIZE = 16
MEDIUM_SIZE = 18
BIGGER_SIZE = 20

plt.rc('font', size=SMALL_SIZE)          # controls default text sizes
plt.rc('axes', titlesize=SMALL_SIZE)     # fontsize of the axes title
plt.rc('axes', labelsize=MEDIUM_SIZE)    # fontsize of the x and y labels
plt.rc('xtick', labelsize=SMALL_SIZE)    # fontsize of the tick labels
plt.rc('ytick', labelsize=SMALL_SIZE)    # fontsize of the tick labels
plt.rc('legend', fontsize=SMALL_SIZE)    # legend fontsize
plt.rc('figure', titlesize=BIGGER_SIZE)  # fontsize of the figure title

print(plt.style.available)
plt.style.use('seaborn-white')
# Out:
# ['seaborn-dark', 'seaborn-darkgrid', 'seaborn-ticks', 'fivethirtyeight', 'seaborn-whitegrid', 'classic', '_classic_test', 'fast', 'seaborn-talk', 'seaborn-dark-palette', 'seaborn-bright', 'seaborn-pastel', 'grayscale', 'seaborn-notebook', 'ggplot', 'seaborn-colorblind', 'seaborn-muted', 'seaborn', 'Solarize_Light2', 'seaborn-paper', 'bmh', 'tableau-colorblind10', 'seaborn-white', 'dark_background', 'seaborn-poster', 'seaborn-deep']

# %%
dt_norm_1_1 = np.load('dtnorm_1_1.npy')
da_a_1_1 = np.load('dA_A_1_1.npy')
dd_d_1_1 = np.load('dD_D_1_1.npy')
dtau_tau_1_1 = np.load('dtau_tau_1_1.npy')
da_a_ind_1_1 = np.load('dA_A_ind_1_1.npy')
dtau_tau_ind_1_1 = np.load('dtau_tau_ind_1_1.npy')

# %%
plt.semilogy(dt_norm_1_1,dd_d_1_1,"o",label=r"$dD/D$")
plt.semilogy(dt_norm_1_1,da_a_1_1,"o",label=r'$dA/A$')
plt.semilogy(dt_norm_1_1,dtau_tau_1_1,"o",label=r'$d\tau/\tau$')
plt.semilogy(dt_norm_1_1,dtau_tau_ind_1_1,color="k",label=r"$d\tau/\tau$ ind")
plt.semilogy(dt_norm_1_1,da_a_ind_1_1,"-.",color="k",label=r"$dA/A$ ind")
plt.xlabel(r'$\Delta t/\tau$')
plt.ylabel("relative error")
#plt.xlim((0,4))
plt.legend(ncol=2)
plt.savefig("optimaldt_1_1.png",format='png',dpi=300,bbox_inches='tight',facecolor="white",backgroundcolor="white")

# %%
dt_norm_1_10 = np.load('dtnorm_1_10.npy')
da_a_1_10 = np.load('dA_A_1_10.npy')
dd_d_1_10 = np.load('dD_D_1_10.npy')
dtau_tau_1_10 = np.load('dtau_tau_1_10.npy')
da_a_ind_1_10 = np.load('dA_A_ind_1_10.npy')
dtau_tau_ind_1_10 = np.load('dtau_tau_ind_1_10.npy')

# %%
plt.semilogy(dt_norm_1_10,dd_d_1_10,"o",label=r"$dD/D$")
plt.semilogy(dt_norm_1_10,da_a_1_10,"o",label=r'$dA/A$')
plt.semilogy(dt_norm_1_10,dtau_tau_1_10,"o",label=r'$d\tau/\tau$')
plt.semilogy(dt_norm_1_10,dtau_tau_ind_1_10,color="k",label=r"$d\tau/\tau$ ind")
plt.semilogy(dt_norm_1_10,da_a_ind_1_10,"-.",color="k",label=r"$dA/A$ ind")
plt.xlabel(r'$\Delta t/\tau$')
plt.ylabel("relative error")
#plt.xlim((0,4))
plt.legend(ncol=2)
plt.savefig("optimaldt_1_10.png",format='png',dpi=300,bbox_inches='tight',facecolor="white",backgroundcolor="white")

# %%
dt_norm_1_01 = np.load('dtnorm_1_01.npy')
da_a_1_01 = np.load('dA_A_1_01.npy')
dd_d_1_01 = np.load('dD_D_1_01.npy')
dtau_tau_1_01 = np.load('dtau_tau_1_01.npy')
da_a_ind_1_01 = np.load('dA_A_ind_1_01.npy')
dtau_tau_ind_1_01 = np.load('dtau_tau_ind_1_01.npy')

# %%
plt.semilogy(dt_norm_1_01,dd_d_1_01,"o",label=r"$dD/D$")
plt.semilogy(dt_norm_1_01,da_a_1_01,"o",label=r'$dA/A$')
plt.semilogy(dt_norm_1_01,dtau_tau_1_01,"o",label=r'$d\tau/\tau$')
plt.semilogy(dt_norm_1_01,dtau_tau_ind_1_01,color="k",label=r"$d\tau/\tau$ ind")
plt.semilogy(dt_norm_1_01,da_a_ind_1_01,"-.",color="k",label=r"$dA/A$ ind")
plt.xlabel(r'$\Delta t/\tau$')
plt.ylabel("relative error")
#plt.xlim((0,4))
plt.legend(ncol=2)
plt.savefig("optimaldt_1_01.png",format='png',dpi=300,bbox_inches='tight',facecolor="white",backgroundcolor="white")

# %%
plt.semilogy(dt_norm_1_01,da_a_1_01,"o",label=r'$dA/A$')
plt.semilogy(dt_norm_1_1,da_a_1_1,"o",label=r'$dA/A$')
plt.semilogy(dt_norm_1_10,da_a_1_10,"o",label=r'$dA/A$')
plt.xlabel(r'$\Delta t/\tau$')
plt.ylabel("relative error")
#plt.xlim((0,4))
plt.legend(ncol=2)
plt.savefig("optimaldt_1_01.png",format='png',dpi=300,bbox_inches='tight',facecolor="white",backgroundcolor="white")

# %%
plt.semilogy(dt_norm_1_01,dd_d_1_01,"o",label=r'$dD/D$')
plt.semilogy(dt_norm_1_1,dd_d_1_1,"o",label=r'$dD/D$')
plt.semilogy(dt_norm_1_10,dd_d_1_10,"o",label=r'$dD/D$')
plt.xlabel(r'$\Delta t/\tau$')
plt.ylabel("relative error")
#plt.xlim((0,4))
plt.legend(ncol=2)
plt.savefig("optimaldt_1_01.png",format='png',dpi=300,bbox_inches='tight',facecolor="white",backgroundcolor="white")

# %%
plt.semilogy(dt_norm_1_1,dtau_tau_1_1,"o",label=r'$d\tau/\tau$')
plt.semilogy(dt_norm_1_01,dtau_tau_1_01,"o",label=r'$d\tau/\tau$')
plt.semilogy(dt_norm_1_10,dtau_tau_1_10,"o",label=r'$d\tau/\tau$')
plt.xlabel(r'$\Delta t/\tau$')
plt.ylabel("relative error")
#plt.xlim((0,4))
plt.legend(ncol=2)
plt.savefig("optimaldt_1_01.png",format='png',dpi=300,bbox_inches='tight',facecolor="white",backgroundcolor="white")

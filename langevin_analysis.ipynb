# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
# %matplotlib inline

# %%
data=pd.read_csv('data.csv')
trace=pd.read_csv('trace.csv')

# %%
plt.plot(data['x'])

# %%
plt.plot(data['acf'])

# %%
plt.plot(trace['t'])

# %%
plt.plot(trace['A'])

# %%
from scipy.stats import gamma,expon
xg=np.linspace(0,80)
hist_t=plt.hist(trace['t'],200,normed=1)
mean_t=trace['t'].mean()
std_t=trace['t'].std()
print('mean: ',mean_t,'std: ',std_t)
scale=std_t**2/mean_t
alpha=mean_t/scale
print('alpha: ',alpha,'beta: ',beta)
gy=gamma.pdf(xg,alpha,scale=scale)
plt.plot(xg,gy)
plt.plot(xg,expon.pdf(xg,scale=10))
# Out:
# mean:  6.847376644943424 std:  5.803015451445706
# alpha:  1.3923261519393029 beta:  0.20333716460120427

# %%
hist_A=plt.hist(trace['A'],200,normed=1)
xA=np.linspace(0,40)
mean_A=trace['A'].mean()
std_A=trace['A'].std()
print('mean: ',mean_A,'std: ',std_A)
scaleA=std_A**2/mean_A
alphaA=mean_A/scaleA
print('alpha: ',alphaA,'scale: ',scaleA)
gA=gamma.pdf(xA,alphaA,scale=scaleA)
plt.plot(xA,gA)
plt.plot(xg,expon.pdf(xA,scale=5))
# Out:
# mean:  3.6458965864908985 std:  3.083975929609983
# alpha:  1.3976123594187926 scale:  2.608660807784407
